# %% [markdown]
# # Optimize Dimensionality Parameters

# %%
import numpy as np
import scipy
from sklearn.decomposition import IncrementalPCA
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import normalize
from sklearn.svm import SVC
import time

import os,sys
sys.path.insert(1, os.path.join(sys.path[0], '../../'))
from retrofit_identity import retrofit_identity
from retrofit_linear   import retrofit_linear
from retrofit_neural   import retrofit_neural
from utils import *

# %%
def make_set(rep, indices):
    return np.array([np.hstack((rep[i], rep[j])) for (i,j) in indices])

def evaluate(X_retrofitted, train_indices, test_indices, rf):
    X_train = make_set(X_retrofitted, train_indices)
    X_test  = make_set(X_retrofitted, test_indices)
    rf.fit(X_train, Y_train)
    return rf.score(X_test, Y_test)

# %%
in_edges = load_obj("in_edges_filtered")
out_edges = load_obj("out_edges_filtered")
X_cooccur_raw = load_obj("X_cooccur")

dummy = DummyClassifier(strategy='most_frequent')
rf = RandomForestClassifier(n_estimators=100)
subgraph = ['has_finding_site', 'has_pathological_process', 'due_to', 'cause_of']

n_iters = 3
scores = {e : {'Raw': [], 'Identity' : [], 'Linear'   : [], 'Neural'   : []} for e in subgraph}
p_train=0.7

# Reduce dimensionality
pca = IncrementalPCA(n_components=25)
X_reduced_25 = pca.fit_transform(X_cooccur_raw)
pca = IncrementalPCA(n_components=10)
X_reduced_10 = pca.fit_transform(X_cooccur_raw)

for edge_type in subgraph:
    print("-"*20 + "\nLeaving out relations of type: '{}'".format(edge_type))
    rels_to_fit = set(subgraph) - set([edge_type])
    in_edges_to_fit = {r: in_edges[r] for r in rels_to_fit}
    out_edges_to_fit = {r: out_edges[r] for r in rels_to_fit}

    # Measure accuracy.
    for iteration in range(1, n_iters+1):
        print("="*60 + "\nIteration: {}\n".format(iteration) + "="*60)

        # Retrofitting.
        t = time.time()
        X_raw = X_reduced_25
        X_ide = retrofit_identity(X_reduced_25, in_edges_to_fit, n_iter=20)
        (X_lin, A, B) = retrofit_linear(X_reduced_25, in_edges_to_fit,
                                        out_edges_to_fit, lam=1e-3, tol=1e-5,
                                        lr=0.5, lr_decay=0.99, n_iter=20)
        (X_neu, A_neu, u_neu, b_neu) = retrofit_neural(X_reduced_10, in_edges_to_fit,
                                           out_edges_to_fit, k=10, lam=1e-5, tol=1e-5,
                                           lr=5e-4, lr_decay=0.99, batch_size=512,
                                           n_iter=200, verbose=10, patience=100)
  
        # Train/test split of evaluation set.
        train_indices, test_indices, neg_train_indices, neg_test_indices = get_train_test_indices(
            in_edges[edge_type], p_train, neg_sampling=1.0)
        Y_train = np.ones(len(train_indices))
        Y_train = np.concatenate((Y_train, np.zeros((len(neg_train_indices), ))))
        Y_test  = np.ones(len(test_indices))
        Y_test  = np.concatenate((Y_test,  np.zeros((len(neg_test_indices),  ))))
        train_indices.extend(neg_train_indices)
        test_indices.extend(neg_test_indices)

        scores[edge_type]["Raw"].append(evaluate(X_raw, train_indices, test_indices, rf))
        scores[edge_type]["Identity"].append(evaluate(X_ide, train_indices, test_indices, rf))
        scores[edge_type]["Linear"].append(evaluate(X_lin, train_indices, test_indices, rf))
        scores[edge_type]["Neural"].append(evaluate(X_neu, train_indices, test_indices, rf))
        print(scores)
    
    print("Sizes for edges of type: '{}' (# train: {:d}, # testing: {:d})".format(
        edge_type, len(Y_train), len(Y_test)))
# Out:
# --------------------
# Leaving out relations of type: 'has_finding_site'
# ============================================================
# Iteration: 1
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.06832	Loss: 2043.907	Patience: 96
# Iteration 20 of 200	Changes: 0.11414	Loss: 2632.676	Patience: 93
# Iteration 30 of 200	Changes: 0.02685	Loss: 14224.726	Patience: 87
# Iteration 40 of 200	Changes: 0.03193	Loss: 1844.953	Patience: 83
# Iteration 50 of 200	Changes: 0.03850	Loss: 1778.633	Patience: 77
# Iteration 60 of 200	Changes: 0.01255	Loss: 2421.690	Patience: 71
# Iteration 70 of 200	Changes: 0.00599	Loss: 763.212	Patience: 66
# Iteration 80 of 200	Changes: 0.02031	Loss: 3745.459	Patience: 61
# Iteration 90 of 200	Changes: 0.00534	Loss: 269.114	Patience: 58
# Iteration 100 of 200	Changes: 0.00303	Loss: 322.118	Patience: 53
# Iteration 110 of 200	Changes: 0.00294	Loss: 673.118	Patience: 48
# Iteration 120 of 200	Changes: 0.00473	Loss: 1083.127	Patience: 41
# Iteration 130 of 200	Changes: 0.00086	Loss: 150.531	Patience: 37
# Iteration 140 of 200	Changes: 0.02214	Loss: 354.277	Patience: 31
# Iteration 150 of 200	Changes: 0.00144	Loss: 66.117	Patience: 27
# Iteration 160 of 200	Changes: 0.00139	Loss: 49.757	Patience: 23
# Iteration 170 of 200	Changes: 0.02849	Loss: 265.984	Patience: 16
# Iteration 180 of 200	Changes: 0.00019	Loss: 857.552	Patience: 11
# Iteration 190 of 200	Changes: 0.00704	Loss: 123.297	Patience: 6
# Iteration 200 of 200	Changes: 0.00093	Loss: 53.633	Patience: 1
# Stopping at iteration 200; change was 0.001
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'has_finding_site': {'Raw': [0.95205563509920232], 'Identity': [0.95226017590509304], 'Neural': [0.9515647371650644], 'Linear': [0.95232153814686027]}, 'has_pathological_process': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}}
# ============================================================
# Iteration: 2
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.07848	Loss: 33500.833	Patience: 96
# Iteration 20 of 200	Changes: 0.04646	Loss: 83239.922	Patience: 90
# Iteration 30 of 200	Changes: 0.75199	Loss: 15043.302	Patience: 84
# Iteration 40 of 200	Changes: 0.05590	Loss: 3482.091	Patience: 80
# Iteration 50 of 200	Changes: 0.01193	Loss: 2253.730	Patience: 75
# Iteration 60 of 200	Changes: 0.00901	Loss: 7676.012	Patience: 69
# Iteration 70 of 200	Changes: 0.00644	Loss: 1076.184	Patience: 66
# Iteration 80 of 200	Changes: 0.02370	Loss: 164.063	Patience: 61
# Iteration 90 of 200	Changes: 0.01547	Loss: 250.529	Patience: 56
# Iteration 100 of 200	Changes: 0.01193	Loss: 1399.677	Patience: 51
# Iteration 110 of 200	Changes: 0.00210	Loss: 414.075	Patience: 46
# Iteration 120 of 200	Changes: 0.00235	Loss: 2249.535	Patience: 40
# Iteration 130 of 200	Changes: 0.00284	Loss: 222.435	Patience: 38
# Iteration 140 of 200	Changes: 0.00181	Loss: 308.744	Patience: 34
# Iteration 150 of 200	Changes: 0.00611	Loss: 188.260	Patience: 28
# Iteration 160 of 200	Changes: 0.00398	Loss: 122.515	Patience: 23
# Iteration 170 of 200	Changes: 0.00037	Loss: 179.012	Patience: 19
# Iteration 180 of 200	Changes: 0.00042	Loss: 57.120	Patience: 16
# Iteration 190 of 200	Changes: 0.00070	Loss: 127.440	Patience: 11
# Iteration 200 of 200	Changes: 0.00177	Loss: 49.103	Patience: 8
# Stopping at iteration 200; change was 0.002
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305], 'Identity': [0.95226017590509304, 0.95276431446644216], 'Neural': [0.9515647371650644, 0.9526821654481229], 'Linear': [0.95232153814686027, 0.95296968701224016]}, 'has_pathological_process': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}}
# ============================================================
# Iteration: 3
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.03517	Loss: 8349.313	Patience: 94
# Iteration 20 of 200	Changes: 0.02620	Loss: 1859.408	Patience: 90
# Iteration 30 of 200	Changes: 0.03039	Loss: 16092.343	Patience: 84
# Iteration 40 of 200	Changes: 0.01973	Loss: 4883.562	Patience: 79
# Iteration 50 of 200	Changes: 0.01500	Loss: 2404.853	Patience: 74
# Iteration 60 of 200	Changes: 0.01101	Loss: 1424.485	Patience: 71
# Iteration 70 of 200	Changes: 0.02718	Loss: 725.474	Patience: 67
# Iteration 80 of 200	Changes: 0.01592	Loss: 2421.991	Patience: 60
# Iteration 90 of 200	Changes: 0.04591	Loss: 1021.719	Patience: 57
# Iteration 100 of 200	Changes: 0.00171	Loss: 372.627	Patience: 52
# Iteration 110 of 200	Changes: 0.00376	Loss: 240.595	Patience: 46
# Iteration 120 of 200	Changes: 0.00834	Loss: 900.257	Patience: 39
# Iteration 130 of 200	Changes: 0.00180	Loss: 145.798	Patience: 35
# Iteration 140 of 200	Changes: 0.00210	Loss: 815.808	Patience: 29
# Iteration 150 of 200	Changes: 0.00338	Loss: 329.637	Patience: 25
# Iteration 160 of 200	Changes: 0.00152	Loss: 208.205	Patience: 22
# Iteration 170 of 200	Changes: 0.00036	Loss: 21.716	Patience: 18
# Iteration 180 of 200	Changes: 0.00094	Loss: 87.374	Patience: 14
# Iteration 190 of 200	Changes: 0.00106	Loss: 91.642	Patience: 9
# Iteration 200 of 200	Changes: 0.00047	Loss: 129.275	Patience: 4
# Stopping at iteration 200; change was 0.000
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}}
# Sizes for edges of type: 'has_finding_site' (# train: 113748, # testing: 49070)
# --------------------
# Leaving out relations of type: 'has_pathological_process'
# ============================================================
# Iteration: 1
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.05207	Loss: 24940.266	Patience: 95
# Iteration 20 of 200	Changes: 0.06285	Loss: 18271.217	Patience: 92
# Iteration 30 of 200	Changes: 0.04530	Loss: 17393.203	Patience: 88
# Iteration 40 of 200	Changes: 0.01946	Loss: 16603.371	Patience: 83
# Iteration 50 of 200	Changes: 0.02547	Loss: 10717.788	Patience: 78
# Iteration 60 of 200	Changes: 0.02551	Loss: 13381.152	Patience: 73
# Iteration 70 of 200	Changes: 0.00810	Loss: 5498.502	Patience: 68
# Iteration 80 of 200	Changes: 0.00420	Loss: 4253.397	Patience: 63
# Iteration 90 of 200	Changes: 0.00407	Loss: 2619.304	Patience: 58
# Iteration 100 of 200	Changes: 0.00503	Loss: 3303.108	Patience: 51
# Iteration 110 of 200	Changes: 0.02154	Loss: 2194.429	Patience: 46
# Iteration 120 of 200	Changes: 0.00322	Loss: 1277.991	Patience: 40
# Iteration 130 of 200	Changes: 0.00226	Loss: 851.828	Patience: 36
# Iteration 140 of 200	Changes: 0.00298	Loss: 865.942	Patience: 31
# Iteration 150 of 200	Changes: 0.00124	Loss: 1219.087	Patience: 25
# Iteration 160 of 200	Changes: 0.00122	Loss: 809.927	Patience: 21
# Iteration 170 of 200	Changes: 0.00093	Loss: 200.860	Patience: 17
# Iteration 180 of 200	Changes: 0.00110	Loss: 221.042	Patience: 14
# Iteration 190 of 200	Changes: 0.00117	Loss: 312.196	Patience: 8
# Iteration 200 of 200	Changes: 0.00021	Loss: 189.086	Patience: 4
# Stopping at iteration 200; change was 0.000
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393], 'Identity': [0.99107992388201716], 'Neural': [0.9936964795432921], 'Linear': [0.9940532825880114]}}
# ============================================================
# Iteration: 2
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.06838	Loss: 20134.108	Patience: 98
# Iteration 20 of 200	Changes: 0.03939	Loss: 14972.829	Patience: 93
# Iteration 30 of 200	Changes: 0.02372	Loss: 13160.949	Patience: 88
# Iteration 40 of 200	Changes: 0.02345	Loss: 12639.933	Patience: 83
# Iteration 50 of 200	Changes: 0.01702	Loss: 12069.869	Patience: 78
# Iteration 60 of 200	Changes: 0.01646	Loss: 8068.967	Patience: 74
# Iteration 70 of 200	Changes: 0.01446	Loss: 6816.200	Patience: 70
# Iteration 80 of 200	Changes: 0.00952	Loss: 6266.390	Patience: 64
# Iteration 90 of 200	Changes: 0.00583	Loss: 3170.638	Patience: 61
# Iteration 100 of 200	Changes: 0.01007	Loss: 1546.499	Patience: 57
# Iteration 110 of 200	Changes: 0.00344	Loss: 3936.116	Patience: 52
# Iteration 120 of 200	Changes: 0.00495	Loss: 1242.184	Patience: 50
# Iteration 130 of 200	Changes: 0.00123	Loss: 997.245	Patience: 45
# Iteration 140 of 200	Changes: 0.00249	Loss: 733.285	Patience: 40
# Iteration 150 of 200	Changes: 0.00407	Loss: 1031.148	Patience: 35
# Iteration 160 of 200	Changes: 0.00425	Loss: 307.744	Patience: 30
# Iteration 170 of 200	Changes: 0.00183	Loss: 648.285	Patience: 25
# Iteration 180 of 200	Changes: 0.00207	Loss: 276.471	Patience: 21
# Iteration 190 of 200	Changes: 0.00056	Loss: 337.640	Patience: 16
# Iteration 200 of 200	Changes: 0.00063	Loss: 251.970	Patience: 11
# Stopping at iteration 200; change was 0.001
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393, 0.98698453608247427], 'Identity': [0.99107992388201716, 0.98943298969072169], 'Neural': [0.9936964795432921, 0.9864690721649485], 'Linear': [0.9940532825880114, 0.99304123711340209]}}
# ============================================================
# Iteration: 3
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.08483	Loss: 14478.105	Patience: 96
# Iteration 20 of 200	Changes: 0.05189	Loss: 32070.880	Patience: 90
# Iteration 30 of 200	Changes: 0.02944	Loss: 4523.275	Patience: 86
# Iteration 40 of 200	Changes: 0.02191	Loss: 8403.120	Patience: 80
# Iteration 50 of 200	Changes: 0.03133	Loss: 4450.633	Patience: 74
# Iteration 60 of 200	Changes: 0.03735	Loss: 4883.845	Patience: 70
# Iteration 70 of 200	Changes: 0.02189	Loss: 3014.429	Patience: 66
# Iteration 80 of 200	Changes: 0.01556	Loss: 4720.510	Patience: 60
# Iteration 90 of 200	Changes: 0.00941	Loss: 3686.120	Patience: 55
# Iteration 100 of 200	Changes: 0.00855	Loss: 4066.068	Patience: 50
# Iteration 110 of 200	Changes: 0.00231	Loss: 3052.452	Patience: 44
# Iteration 120 of 200	Changes: 0.00141	Loss: 833.364	Patience: 40
# Iteration 130 of 200	Changes: 0.00109	Loss: 942.889	Patience: 36
# Iteration 140 of 200	Changes: 0.00693	Loss: 1688.438	Patience: 32
# Iteration 150 of 200	Changes: 0.00104	Loss: 757.950	Patience: 27
# Iteration 160 of 200	Changes: 0.00418	Loss: 648.731	Patience: 22
# Iteration 170 of 200	Changes: 0.00041	Loss: 667.300	Patience: 18
# Iteration 180 of 200	Changes: 0.00065	Loss: 487.526	Patience: 12
# Iteration 190 of 200	Changes: 0.00147	Loss: 591.019	Patience: 8
# Iteration 200 of 200	Changes: 0.00268	Loss: 247.430	Patience: 3
# Stopping at iteration 200; change was 0.003
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393, 0.98698453608247427, 0.98670605612998519], 'Identity': [0.99107992388201716, 0.98943298969072169, 0.98953717380600692], 'Neural': [0.9936964795432921, 0.9864690721649485, 0.98818316100443127], 'Linear': [0.9940532825880114, 0.99304123711340209, 0.99236829148202854]}}
# Sizes for edges of type: 'has_pathological_process' (# train: 19318, # testing: 8124)
# --------------------
# Leaving out relations of type: 'due_to'
# ============================================================
# Iteration: 1
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.04892	Loss: 16406.869	Patience: 98
# Iteration 20 of 200	Changes: 0.05356	Loss: 24887.282	Patience: 92
# Iteration 30 of 200	Changes: 0.02757	Loss: 13038.240	Patience: 89
# Iteration 40 of 200	Changes: 0.02816	Loss: 9130.377	Patience: 83
# Iteration 50 of 200	Changes: 0.01348	Loss: 8740.055	Patience: 79
# Iteration 60 of 200	Changes: 0.01048	Loss: 4325.891	Patience: 74
# Iteration 70 of 200	Changes: 0.01109	Loss: 3738.001	Patience: 68
# Iteration 80 of 200	Changes: 0.00567	Loss: 2746.375	Patience: 62
# Iteration 90 of 200	Changes: 0.04442	Loss: 1857.716	Patience: 56
# Iteration 100 of 200	Changes: 0.00273	Loss: 3887.454	Patience: 49
# Iteration 110 of 200	Changes: 0.00162	Loss: 742.184	Patience: 45
# Iteration 120 of 200	Changes: 0.00172	Loss: 1854.594	Patience: 39
# Iteration 130 of 200	Changes: 0.00427	Loss: 1260.460	Patience: 35
# Iteration 140 of 200	Changes: 0.00399	Loss: 610.661	Patience: 30
# Iteration 150 of 200	Changes: 0.00121	Loss: 426.574	Patience: 25
# Iteration 160 of 200	Changes: 0.00048	Loss: 291.046	Patience: 22
# Iteration 170 of 200	Changes: 0.00030	Loss: 409.753	Patience: 17
# Iteration 180 of 200	Changes: 0.00042	Loss: 152.149	Patience: 13
# Iteration 190 of 200	Changes: 0.00040	Loss: 169.290	Patience: 9
# Iteration 200 of 200	Changes: 0.00204	Loss: 394.772	Patience: 4
# Stopping at iteration 200; change was 0.002
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [0.92337164750957856], 'Identity': [0.94827586206896552], 'Neural': [0.92241379310344829], 'Linear': [0.93821839080459768]}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393, 0.98698453608247427, 0.98670605612998519], 'Identity': [0.99107992388201716, 0.98943298969072169, 0.98953717380600692], 'Neural': [0.9936964795432921, 0.9864690721649485, 0.98818316100443127], 'Linear': [0.9940532825880114, 0.99304123711340209, 0.99236829148202854]}}
# ============================================================
# Iteration: 2
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.05771	Loss: 17813.343	Patience: 98
# Iteration 20 of 200	Changes: 0.09131	Loss: 13342.684	Patience: 92
# Iteration 30 of 200	Changes: 0.04511	Loss: 9389.056	Patience: 87
# Iteration 40 of 200	Changes: 0.02834	Loss: 29805.172	Patience: 81
# Iteration 50 of 200	Changes: 0.01249	Loss: 4674.306	Patience: 76
# Iteration 60 of 200	Changes: 0.01688	Loss: 10705.260	Patience: 71
# Iteration 70 of 200	Changes: 0.00581	Loss: 6061.835	Patience: 65
# Iteration 80 of 200	Changes: 0.00572	Loss: 5636.531	Patience: 58
# Iteration 90 of 200	Changes: 0.00730	Loss: 3478.852	Patience: 53
# Iteration 100 of 200	Changes: 0.00255	Loss: 521.047	Patience: 49
# Iteration 110 of 200	Changes: 0.00536	Loss: 1903.028	Patience: 43
# Iteration 120 of 200	Changes: 0.00331	Loss: 2419.228	Patience: 37
# Iteration 130 of 200	Changes: 0.00184	Loss: 2365.397	Patience: 31
# Iteration 140 of 200	Changes: 0.00049	Loss: 663.396	Patience: 25
# Iteration 150 of 200	Changes: 0.00185	Loss: 709.757	Patience: 21
# Iteration 160 of 200	Changes: 0.00059	Loss: 347.550	Patience: 17
# Iteration 170 of 200	Changes: 0.00144	Loss: 441.362	Patience: 14
# Iteration 180 of 200	Changes: 0.00075	Loss: 320.798	Patience: 8
# Iteration 190 of 200	Changes: 0.00291	Loss: 127.825	Patience: 4
# Loss reached local minimum (and patience expired) at iteration 198
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [0.92337164750957856, 0.90263405456255874], 'Identity': [0.94827586206896552, 0.93885230479774229], 'Neural': [0.92241379310344829, 0.9063969896519285], 'Linear': [0.93821839080459768, 0.92850423330197551]}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393, 0.98698453608247427, 0.98670605612998519], 'Identity': [0.99107992388201716, 0.98943298969072169, 0.98953717380600692], 'Neural': [0.9936964795432921, 0.9864690721649485, 0.98818316100443127], 'Linear': [0.9940532825880114, 0.99304123711340209, 0.99236829148202854]}}
# ============================================================
# Iteration: 3
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.03442	Loss: 12601.817	Patience: 97
# Iteration 20 of 200	Changes: 0.08312	Loss: 12256.596	Patience: 92
# Iteration 30 of 200	Changes: 0.02642	Loss: 13713.668	Patience: 87
# Iteration 40 of 200	Changes: 0.01543	Loss: 6529.844	Patience: 82
# Iteration 50 of 200	Changes: 0.02107	Loss: 12459.066	Patience: 76
# Iteration 60 of 200	Changes: 0.00764	Loss: 3192.434	Patience: 73
# Iteration 70 of 200	Changes: 0.01458	Loss: 6437.067	Patience: 67
# Iteration 80 of 200	Changes: 0.00507	Loss: 5410.513	Patience: 62
# Iteration 90 of 200	Changes: 0.00451	Loss: 2635.749	Patience: 59
# Iteration 100 of 200	Changes: 0.00452	Loss: 3484.535	Patience: 54
# Iteration 110 of 200	Changes: 0.00304	Loss: 2177.833	Patience: 50
# Iteration 120 of 200	Changes: 0.00123	Loss: 947.789	Patience: 46
# Iteration 130 of 200	Changes: 0.00264	Loss: 613.561	Patience: 41
# Iteration 140 of 200	Changes: 0.00117	Loss: 478.086	Patience: 36
# Iteration 150 of 200	Changes: 0.00067	Loss: 1164.486	Patience: 31
# Iteration 160 of 200	Changes: 0.00033	Loss: 619.874	Patience: 28
# Iteration 170 of 200	Changes: 0.00059	Loss: 530.368	Patience: 23
# Iteration 180 of 200	Changes: 0.00022	Loss: 383.864	Patience: 18
# Iteration 190 of 200	Changes: 0.00021	Loss: 260.879	Patience: 12
# Iteration 200 of 200	Changes: 0.00248	Loss: 308.464	Patience: 7
# Stopping at iteration 200; change was 0.002
# {'cause_of': {'Raw': [], 'Identity': [], 'Neural': [], 'Linear': []}, 'due_to': {'Raw': [0.92337164750957856, 0.90263405456255874, 0.91821743388834476], 'Identity': [0.94827586206896552, 0.93885230479774229, 0.95347698334965725], 'Neural': [0.92241379310344829, 0.9063969896519285, 0.91821743388834476], 'Linear': [0.93821839080459768, 0.92850423330197551, 0.93829578844270323]}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393, 0.98698453608247427, 0.98670605612998519], 'Identity': [0.99107992388201716, 0.98943298969072169, 0.98953717380600692], 'Neural': [0.9936964795432921, 0.9864690721649485, 0.98818316100443127], 'Linear': [0.9940532825880114, 0.99304123711340209, 0.99236829148202854]}}
# Sizes for edges of type: 'due_to' (# train: 5042, # testing: 2042)
# --------------------
# Leaving out relations of type: 'cause_of'
# ============================================================
# Iteration: 1
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.06609	Loss: 32620.084	Patience: 96
# Iteration 20 of 200	Changes: 0.03813	Loss: 14748.898	Patience: 90
# Iteration 30 of 200	Changes: 0.04350	Loss: 6278.117	Patience: 86
# Iteration 40 of 200	Changes: 0.02366	Loss: 8222.491	Patience: 80
# Iteration 50 of 200	Changes: 0.02199	Loss: 11650.767	Patience: 75
# Iteration 60 of 200	Changes: 0.09613	Loss: 10554.806	Patience: 69
# Iteration 70 of 200	Changes: 0.00375	Loss: 1834.607	Patience: 64
# Iteration 80 of 200	Changes: 0.00439	Loss: 2974.436	Patience: 57
# Iteration 90 of 200	Changes: 0.00291	Loss: 5060.776	Patience: 52
# Iteration 100 of 200	Changes: 0.00590	Loss: 3326.456	Patience: 48
# Iteration 110 of 200	Changes: 0.00218	Loss: 1925.622	Patience: 44
# Iteration 120 of 200	Changes: 0.00143	Loss: 1284.751	Patience: 39
# Iteration 130 of 200	Changes: 0.00159	Loss: 476.590	Patience: 34
# Iteration 140 of 200	Changes: 0.00083	Loss: 1609.049	Patience: 29
# Iteration 150 of 200	Changes: 0.00064	Loss: 732.001	Patience: 25
# Iteration 160 of 200	Changes: 0.00061	Loss: 323.092	Patience: 21
# Iteration 170 of 200	Changes: 0.00016	Loss: 464.392	Patience: 16
# Iteration 180 of 200	Changes: 0.00010	Loss: 288.463	Patience: 12
# Iteration 190 of 200	Changes: 0.00008	Loss: 139.922	Patience: 8
# Iteration 200 of 200	Changes: 0.00008	Loss: 154.596	Patience: 3
# Stopping at iteration 200; change was 0.000
# {'cause_of': {'Raw': [0.78306878306878303], 'Identity': [0.86507936507936511], 'Neural': [0.81216931216931221], 'Linear': [0.80952380952380953]}, 'due_to': {'Raw': [0.92337164750957856, 0.90263405456255874, 0.91821743388834476], 'Identity': [0.94827586206896552, 0.93885230479774229, 0.95347698334965725], 'Neural': [0.92241379310344829, 0.9063969896519285, 0.91821743388834476], 'Linear': [0.93821839080459768, 0.92850423330197551, 0.93829578844270323]}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393, 0.98698453608247427, 0.98670605612998519], 'Identity': [0.99107992388201716, 0.98943298969072169, 0.98953717380600692], 'Neural': [0.9936964795432921, 0.9864690721649485, 0.98818316100443127], 'Linear': [0.9940532825880114, 0.99304123711340209, 0.99236829148202854]}}
# ============================================================
# Iteration: 2
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.03327	Loss: 12841.151	Patience: 95
# Iteration 20 of 200	Changes: 0.03942	Loss: 15602.540	Patience: 88
# Iteration 30 of 200	Changes: 0.03556	Loss: 11118.174	Patience: 82
# Iteration 40 of 200	Changes: 0.01748	Loss: 8501.361	Patience: 77
# Iteration 50 of 200	Changes: 0.02515	Loss: 12306.264	Patience: 73
# Iteration 60 of 200	Changes: 0.00831	Loss: 4583.325	Patience: 69
# Iteration 70 of 200	Changes: 0.00783	Loss: 6363.595	Patience: 63
# Iteration 80 of 200	Changes: 0.00704	Loss: 6754.040	Patience: 59
# Iteration 90 of 200	Changes: 0.03658	Loss: 2263.105	Patience: 54
# Iteration 100 of 200	Changes: 0.00429	Loss: 3540.348	Patience: 48
# Iteration 110 of 200	Changes: 0.00333	Loss: 2204.509	Patience: 43
# Iteration 120 of 200	Changes: 0.00264	Loss: 1575.100	Patience: 40
# Iteration 130 of 200	Changes: 0.00065	Loss: 1471.955	Patience: 34
# Iteration 140 of 200	Changes: 0.00136	Loss: 1403.495	Patience: 29
# Iteration 150 of 200	Changes: 0.00042	Loss: 765.081	Patience: 23
# Iteration 160 of 200	Changes: 0.00059	Loss: 705.769	Patience: 17
# Iteration 170 of 200	Changes: 0.00139	Loss: 491.917	Patience: 13
# Iteration 180 of 200	Changes: 0.00031	Loss: 289.841	Patience: 8
# Iteration 190 of 200	Changes: 0.00008	Loss: 209.956	Patience: 3
# Loss reached local minimum (and patience expired) at iteration 196
# {'cause_of': {'Raw': [0.78306878306878303, 0.81000000000000005], 'Identity': [0.86507936507936511, 0.85199999999999998], 'Neural': [0.81216931216931221, 0.80400000000000005], 'Linear': [0.80952380952380953, 0.80200000000000005]}, 'due_to': {'Raw': [0.92337164750957856, 0.90263405456255874, 0.91821743388834476], 'Identity': [0.94827586206896552, 0.93885230479774229, 0.95347698334965725], 'Neural': [0.92241379310344829, 0.9063969896519285, 0.91821743388834476], 'Linear': [0.93821839080459768, 0.92850423330197551, 0.93829578844270323]}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393, 0.98698453608247427, 0.98670605612998519], 'Identity': [0.99107992388201716, 0.98943298969072169, 0.98953717380600692], 'Neural': [0.9936964795432921, 0.9864690721649485, 0.98818316100443127], 'Linear': [0.9940532825880114, 0.99304123711340209, 0.99236829148202854]}}
# ============================================================
# Iteration: 3
# ============================================================
# Loss reached local minimum at iteration 1
# Iteration 10 of 200	Changes: 0.08764	Loss: 36623.350	Patience: 95
# Iteration 20 of 200	Changes: 0.06775	Loss: 14782.703	Patience: 91
# Iteration 30 of 200	Changes: 0.02467	Loss: 7861.191	Patience: 86
# Iteration 40 of 200	Changes: 0.01535	Loss: 5518.504	Patience: 81
# Iteration 50 of 200	Changes: 0.12343	Loss: 5445.009	Patience: 75
# Iteration 60 of 200	Changes: 0.01730	Loss: 7399.395	Patience: 70
# Iteration 70 of 200	Changes: 0.01162	Loss: 5497.138	Patience: 65
# Iteration 80 of 200	Changes: 0.01062	Loss: 4654.133	Patience: 59
# Iteration 90 of 200	Changes: 0.00603	Loss: 2879.173	Patience: 55
# Iteration 100 of 200	Changes: 0.03617	Loss: 3868.330	Patience: 52
# Iteration 110 of 200	Changes: 0.00200	Loss: 1743.926	Patience: 48
# Iteration 120 of 200	Changes: 0.00388	Loss: 1906.446	Patience: 44
# Iteration 130 of 200	Changes: 0.00124	Loss: 2725.260	Patience: 39
# Iteration 140 of 200	Changes: 0.00319	Loss: 1015.454	Patience: 34
# Iteration 150 of 200	Changes: 0.00035	Loss: 526.406	Patience: 28
# Iteration 160 of 200	Changes: 0.00108	Loss: 177.512	Patience: 24
# Iteration 170 of 200	Changes: 0.00364	Loss: 260.732	Patience: 19
# Iteration 180 of 200	Changes: 0.00010	Loss: 226.601	Patience: 13
# Iteration 190 of 200	Changes: 0.00041	Loss: 176.715	Patience: 8
# Iteration 200 of 200	Changes: 0.00162	Loss: 219.858	Patience: 2
# Stopping at iteration 200; change was 0.002
# {'cause_of': {'Raw': [0.78306878306878303, 0.81000000000000005, 0.79521276595744683], 'Identity': [0.86507936507936511, 0.85199999999999998, 0.88297872340425532], 'Neural': [0.81216931216931221, 0.80400000000000005, 0.79255319148936165], 'Linear': [0.80952380952380953, 0.80200000000000005, 0.81382978723404253]}, 'due_to': {'Raw': [0.92337164750957856, 0.90263405456255874, 0.91821743388834476], 'Identity': [0.94827586206896552, 0.93885230479774229, 0.95347698334965725], 'Neural': [0.92241379310344829, 0.9063969896519285, 0.91821743388834476], 'Linear': [0.93821839080459768, 0.92850423330197551, 0.93829578844270323]}, 'has_finding_site': {'Raw': [0.95205563509920232, 0.95266162819354305, 0.95188506215610358], 'Identity': [0.95226017590509304, 0.95276431446644216, 0.95133482779702461], 'Neural': [0.9515647371650644, 0.9526821654481229, 0.95153861830038722], 'Linear': [0.95232153814686027, 0.95296968701224016, 0.95214998981047483]}, 'has_pathological_process': {'Raw': [0.98751189343482393, 0.98698453608247427, 0.98670605612998519], 'Identity': [0.99107992388201716, 0.98943298969072169, 0.98953717380600692], 'Neural': [0.9936964795432921, 0.9864690721649485, 0.98818316100443127], 'Linear': [0.9940532825880114, 0.99304123711340209, 0.99236829148202854]}}
# Sizes for edges of type: 'cause_of' (# train: 1166, # testing: 376)

# %%
for edge_type, method_scores in scores.items():
    print("="*40+"\n{}".format(edge_type))
    for method_name, accs in method_scores.items():
        print("Method: {}\t\t{:.4f}+-{:.4f}".format(method_name, np.mean(accs), np.std(accs)))
# Out:
# ========================================
# cause_of
# Method: Raw		0.7961+-0.0110
# Method: Identity		0.8667+-0.0127
# Method: Neural		0.8029+-0.0080
# Method: Linear		0.8085+-0.0049
# ========================================
# due_to
# Method: Raw		0.9147+-0.0088
# Method: Identity		0.9469+-0.0061
# Method: Neural		0.9157+-0.0068
# Method: Linear		0.9350+-0.0046
# ========================================
# has_finding_site
# Method: Raw		0.9522+-0.0003
# Method: Identity		0.9521+-0.0006
# Method: Neural		0.9519+-0.0005
# Method: Linear		0.9525+-0.0004
# ========================================
# has_pathological_process
# Method: Raw		0.9871+-0.0003
# Method: Identity		0.9900+-0.0008
# Method: Neural		0.9894+-0.0031
# Method: Linear		0.9932+-0.0007
